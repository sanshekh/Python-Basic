# %% [markdown]
# # Generate cvv for the credit card ,and create dictionary

# %%
name=[]
cell_number=[]
cards_valid=[]
user=0
while user<=4:
    card_number=str(input("Enter your card number \n"))
    if (len(card_number)==14 or len(card_number)==16):
        month=int(input("Enter the month \n"))
        year=int(input("Enter the year \n"))
    else:
        print("invalid, enter again \n")
        continue
        
    if (month>=1 and month<=12) and year>=2020:
            cards_valid.append(card_number)
            user=user+1
            my_name=str(input("Enter your name \n"))
            name.append(my_name)
            my_number=int(input("Enter your mobile number \n"))
            cell_number.append(my_number)
    else:
        print("invalid card \n")
        continue
            

        

from random import randint
my_cvv=[randint(100,999),randint(100,999),randint(100,999),randint(100,999),randint(100,999)]
print(my_cvv)

cell_cvv={cell_number[i]:my_cvv[i] for i in range(len(cell_number))}
print(cell_cvv)

my_bank_dic={cards_valid[i]:{cell_number[i]:name[i]} for i in range(len(cards_valid))}
print(my_bank_dic)
# Out:
# Enter your card number
# 123456789123456
# invalid, enter again
#
# Enter your card number
# 1234567812345678
# Enter the month
# 2
# Enter the year
# 2019
# invalid card
#
# Enter your card number
# 1234567812345678
# Enter the month
# 2
# Enter the year
# 2021
# Enter your name
# san skr
# Enter your mobile number
# 8765432162
# Enter your card number
# 1234568712345876
# Enter the month
# 3
# Enter the year
# 2022
# Enter your name
# saf gfd
# Enter your mobile number
# 4518757191134
# Enter your card number
# 8765432187653421
# Enter the month
# 5
# Enter the year
# 2020
# Enter your name
# dsjk djafl
# Enter your mobile number
# 371864995954460
# Enter your card number
# 9876543287654321
# Enter the month
# 3
# Enter the year
# 2021
# Enter your name
# dfaf jbfjd
# Enter your mobile number
# 437815349545820
# Enter your card number
# 1243567812345678
# Enter the month
# 9
# Enter the year
# 2021
# Enter your name
# ds jfl
# Enter your mobile number
# 59862559471456
# [601, 268, 465, 682, 979]
# {8765432162: 601, 4518757191134: 268, 371864995954460: 465, 437815349545820: 682, 59862559471456: 979}
# {'1234567812345678': {8765432162: 'san skr'}, '1234568712345876': {4518757191134: 'saf gfd'}, '8765432187653421': {371864995954460: 'dsjk djafl'}, '9876543287654321': {437815349545820: 'dfaf jbfjd'}, '1243567812345678': {59862559471456: 'ds jfl'}}
